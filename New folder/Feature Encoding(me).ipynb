# %% [markdown]
# # One hot encoding

# %%
import pandas as pd

# %%
df = pd.read_csv('airport.csv')

# %%
df.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.949200    -151.695999         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# 0      Bensalem                no      00A       NaN        00A       NaN
# 1         Leoti                no     00AA       NaN       00AA       NaN
# 2  Anchor Point                no     00AK       NaN       00AK       NaN
# 3       Harvest                no     00AL       NaN       00AL       NaN
# 4       Newport                no      NaN       NaN        NaN       NaN
#
#   wikipedia_link keywords
# 0            NaN      NaN
# 1            NaN      NaN
# 2            NaN      NaN
# 3            NaN      NaN
# 4            NaN     00AR

# %%
df['type'].value_counts()
# Out:
# type
# small_airport     35696
# heliport          13613
# closed             5683
# medium_airport     4532
# seaplane_base      1045
# large_airport       617
# balloonport          35
# Name: count, dtype: int64

# %%
pd.get_dummies(df,columns=['type'])
# Out:
#            id    ident                                name  latitude_deg  \
# 0        6523      00A                   Total Rf Heliport     40.070801
# 1      323361     00AA                Aero B Ranch Airport     38.704022
# 2        6524     00AK                        Lowell Field     59.949200
# 3        6525     00AL                        Epps Airpark     34.864799
# 4        6526     00AR  Newport Hospital & Clinic Heliport     35.608700
# ...       ...      ...                                 ...           ...
# 61216  317861     ZYYK               Yingkou Lanqi Airport     40.542524
# 61217   32753     ZYYY             Shenyang Dongta Airport     41.784401
# 61218   46378  ZZ-0001                     Sealand Helipad     51.894444
# 61219  307326  ZZ-0002           Glorioso Islands Airstrip    -11.584278
# 61220  313629     ZZZZ              Satsuma Iōjima Airport     30.784722
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 0         -74.933601          11.0       NaN          US      US-PA
# 1        -101.473911        3435.0       NaN          US      US-KS
# 2        -151.695999         450.0       NaN          US      US-AK
# 3         -86.770302         820.0       NaN          US      US-AL
# 4         -91.254898         237.0       NaN          US      US-AR
# ...              ...           ...       ...         ...        ...
# 61216     122.358600           NaN        AS          CN      CN-21
# 61217     123.496002           NaN        AS          CN      CN-21
# 61218       1.482500          40.0        EU          GB     GB-ENG
# 61219      47.296389          11.0        AF          TF     TF-U-A
# 61220     130.270556         338.0        AS          JP      JP-46
#
#            municipality  ...                   home_link  \
# 0              Bensalem  ...                         NaN
# 1                 Leoti  ...                         NaN
# 2          Anchor Point  ...                         NaN
# 3               Harvest  ...                         NaN
# 4               Newport  ...                         NaN
# ...                 ...  ...                         ...
# 61216  Laobian, Yingkou  ...                         NaN
# 61217  Dadong, Shenyang  ...                         NaN
# 61218           Sealand  ...  http://www.sealandgov.org/
# 61219  Grande Glorieuse  ...                         NaN
# 61220      Mishima-Mura  ...                         NaN
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 61216  https://en.wikipedia.org/wiki/Yingkou_Lanqi_Ai...
# 61217                                                NaN
# 61218  https://en.wikipedia.org/wiki/Principality_of_...
# 61219                                                NaN
# 61220  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                    keywords type_balloonport type_closed type_heliport  \
# 0                       NaN            False       False          True
# 1                       NaN            False       False         False
# 2                       NaN            False       False         False
# 3                       NaN            False       False         False
# 4                      00AR            False        True         False
# ...                     ...              ...         ...           ...
# 61216                   NaN            False       False         False
# 61217                   NaN            False       False         False
# 61218  Roughs Tower Helipad            False       False          True
# 61219                   NaN            False       False         False
# 61220  SATSUMA,IWOJIMA,RJX7            False       False         False
#
#       type_large_airport  type_medium_airport  type_seaplane_base  \
# 0                  False                False               False
# 1                  False                False               False
# 2                  False                False               False
# 3                  False                False               False
# 4                  False                False               False
# ...                  ...                  ...                 ...
# 61216              False                 True               False
# 61217              False                 True               False
# 61218              False                False               False
# 61219              False                False               False
# 61220              False                False               False
#
#        type_small_airport
# 0                   False
# 1                    True
# 2                    True
# 3                    True
# 4                   False
# ...                   ...
# 61216               False
# 61217               False
# 61218               False
# 61219                True
# 61220                True
#
# [61221 rows x 24 columns]

# %% [markdown]
# # Label Encoding

# %%
import pandas as pd
df1 = pd.read_csv('Iris.csv')

# %%
df1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1['Species']=le.fit_transform(df1['Species'])

# %%
df1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
df1.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
