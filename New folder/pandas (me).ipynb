# %%
# !pip install pandas

# %%
import pandas as pd

# %%
l1 = [3,6,8,10,30]

# %%
s1 = pd.Series(l1)

# %%
s1
# Out:
# 0     3
# 1     6
# 2     8
# 3    10
# 4    30
# dtype: int64

# %%
d1 ={"one":10,"second":100,"third":1000}

# %%
s2 = pd.Series(d1) #series

# %%
s2
# Out:
# one         10
# second     100
# third     1000
# dtype: int64

# %%
smaple_data = {
    "weekdays": ["sunday","monday","tuseday"],
    "test_score":[10,20,30]
}

# %%
df = pd.DataFrame(smaple_data) #dataframe

# %%
df
# Out:
#   weekdays  test_score
# 0   sunday          10
# 1   monday          20
# 2  tuseday          30

# %%
 df.loc[0]   #locate function
# Out:
# weekdays      sunday
# test_score        10
# Name: 0, dtype: object

# %%
df = pd.read_csv('airport.csv')

# %%
df
# Out:
#            id    ident            type                                name  \
# 0        6523      00A        heliport                   Total Rf Heliport
# 1      323361     00AA   small_airport                Aero B Ranch Airport
# 2        6524     00AK   small_airport                        Lowell Field
# 3        6525     00AL   small_airport                        Epps Airpark
# 4        6526     00AR          closed  Newport Hospital & Clinic Heliport
# ...       ...      ...             ...                                 ...
# 61216  317861     ZYYK  medium_airport               Yingkou Lanqi Airport
# 61217   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 61218   46378  ZZ-0001        heliport                     Sealand Helipad
# 61219  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 61220  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
# ...

# %%
df.head()   #it will show top 5 rows
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.949200    -151.695999         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# ...

# %%
df.head(10)  # if u want to see top 10 then we use it.
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
# 5  322127  00AS  small_airport                      Fulton Airport
# 6    6527  00AZ  small_airport                      Cordes Airport
# 7    6528  00CA  small_airport             Goldstone /Gts/ Airport
# 8  324424  00CL  small_airport                 Williams Ag Airport
# 9  322658  00CN       heliport     Kitchen Creek Helibase Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# ...

# %%
df.tail() #it will show last 5 rows
# Out:
#            id    ident            type                       name  \
# 61216  317861     ZYYK  medium_airport      Yingkou Lanqi Airport
# 61217   32753     ZYYY  medium_airport    Shenyang Dongta Airport
# 61218   46378  ZZ-0001        heliport            Sealand Helipad
# 61219  307326  ZZ-0002   small_airport  Glorioso Islands Airstrip
# 61220  313629     ZZZZ   small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 61216     40.542524     122.358600           NaN        AS          CN
# 61217     41.784401     123.496002           NaN        AS          CN
# 61218     51.894444       1.482500          40.0        EU          GB
# 61219    -11.584278      47.296389          11.0        AF          TF
# 61220     30.784722     130.270556         338.0        AS          JP
#
#       iso_region      municipality scheduled_service gps_code iata_code  \
# ...

# %%
df.tail(7) #last 7 rows
# Out:
#            id    ident            type  \
# 61214   27243     ZYTX   large_airport
# 61215   27244     ZYYJ  medium_airport
# 61216  317861     ZYYK  medium_airport
# 61217   32753     ZYYY  medium_airport
# 61218   46378  ZZ-0001        heliport
# 61219  307326  ZZ-0002   small_airport
# 61220  313629     ZZZZ   small_airport
#
#                                          name  latitude_deg  longitude_deg  \
# 61214  Shenyang Taoxian International Airport     41.639801     123.483002
# 61215             Yanji Chaoyangchuan Airport     42.882801     129.451004
# 61216                   Yingkou Lanqi Airport     40.542524     122.358600
# 61217                 Shenyang Dongta Airport     41.784401     123.496002
# 61218                         Sealand Helipad     51.894444       1.482500
# 61219               Glorioso Islands Airstrip    -11.584278      47.296389
# 61220                  Satsuma Iōjima Airport     30.784722     130.270556
#
# ...

# %%
df.info() #it will give me the basic information about all columns presrnt in the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61221 entries, 0 to 61220
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 61221 non-null  int64
#  1   ident              61221 non-null  object
#  2   type               61221 non-null  object
#  3   name               61221 non-null  object
#  4   latitude_deg       61221 non-null  float64
#  5   longitude_deg      61221 non-null  float64
#  6   elevation_ft       50756 non-null  float64
#  7   continent          30831 non-null  object
#  8   iso_country        60975 non-null  object
#  9   iso_region         61221 non-null  object
#  10  municipality       55403 non-null  object
#  11  scheduled_service  61221 non-null  object
#  12  gps_code           41983 non-null  object
#  13  iata_code          9238 non-null   object
#  14  local_code         31082 non-null  object
#  15  home_link          3213 non-null   object
# ...

# %%
df.describe() #it will describe all the numerical features present in dataset
# Out:
#                   id  latitude_deg  longitude_deg  elevation_ft
# count   61221.000000  61221.000000   61221.000000  50756.000000
# mean   109136.256448     25.723124     -33.700662   1259.060151
# std    137305.861393     26.873691      81.927034   1614.654213
# min         2.000000    -90.000000    -179.876999  -1266.000000
# 25%     15438.000000      9.325090     -93.182899    207.000000
# 50%     30995.000000     35.688620     -71.456596    726.000000
# 75%    312953.000000     43.422199      15.766528   1539.000000
# max    340025.000000     82.750000     179.975700  22000.000000
